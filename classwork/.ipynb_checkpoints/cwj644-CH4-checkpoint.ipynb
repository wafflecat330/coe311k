# %%
import numpy as np

# %%
sum = 0
truePi = np.pi

for i in range(5000):
    sum = sum + 4*(( (-1)**i) / (2*i+1))
    if ((i + 1)%100) == 0:
        print("Relative error at term",(i),":", (abs(truePi-sum)/truePi)), "%"
# Out:
# Relative error at term 99 : 0.00318301929431018
# Relative error at term 199 : 0.001591539484045989
# Relative error at term 299 : 0.001061030006672841
# Relative error at term 399 : 0.0007957734720706582
# Relative error at term 499 : 0.000636619135750372
# Relative error at term 599 : 0.0005305161085596649
# Relative error at term 699 : 0.00045472817682973846
# Relative error at term 799 : 0.00039788720230457477
# Relative error at term 899 : 0.000353677542155349
# Relative error at term 999 : 0.0003183098066059948
# Relative error at term 1099 : 0.00028937256401525733
# Relative error at term 1199 : 0.0002652581924342223
# Relative error at term 1299 : 0.00024485372238193846
# Relative error at term 1399 : 0.0002273641754167515
# Relative error at term 1499 : 0.00021220656721108246
# Relative error at term 1599 : 0.00019894365943672938
# Relative error at term 1699 : 0.00018724109332290856
# Relative error at term 1799 : 0.0001768388120132509
# ...
