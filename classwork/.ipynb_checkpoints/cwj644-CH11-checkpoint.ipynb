# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline

# %%
# Define known data points
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([0, 1, 0, 1, 0, 1])

# Create a cubic spline interpolation of the data
cs = CubicSpline(x, y, bc_type='natural') 

# Generate new x values for a smooth plot
x_interp = np.linspace(0, 5, 100)
y_interp = cs(x_interp)



#Polynomial fit
coefficients = np.polyfit(x, y, 3)
polynomial = np.poly1d(coefficients)
y_polpred = polynomial(x_interp)

# %%
plt.figure()
plt.scatter(x, y, color='purple', label='Original Data')
plt.plot(x_interp, y_interp, color='red', label='Cubic Spline Interpolation')
plt.plot(x_interp, y_polpred, color='blue', label='Polynomial Fit')

plt.title("Cubic Spline vs PolyFit")
plt.xlabel("x")
plt.ylabel('y')
plt.legend()
plt.show()
